# %% [markdown]
# # Final Project – Data Science Tools & Ecosystem

# %% [markdown]
# Welcome! This notebook completes the final project by demonstrating basic Markdown, tables, and a few short Python code cells.
# It showcases common **languages**, **libraries**, and **tools** used across the data science ecosystem.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL

# %% [markdown]
# ## Data Science Libraries
# - NumPy
# - pandas
# - Matplotlib / Seaborn
# - scikit-learn
# - TensorFlow / Keras
# - Plotly
# - NLTK / spaCy

# %% [markdown]
# ## Data Science Tools
# | Tool              | Category            | Typical Use                                   |
# |-------------------|---------------------|-----------------------------------------------|
# | JupyterLab        | Notebook IDE        | Interactive computing, visualization          |
# | VS Code           | Editor/IDE          | General development and extensions            |
# | Git               | Version Control     | Track changes and collaborate                  |
# | GitHub            | Repo Hosting        | Share code/notebooks publicly                  |
# | Apache Spark      | Big Data Framework  | Distributed processing                          |
# | Hadoop (HDFS/YARN)| Big Data Platform   | Distributed storage & resource mgmt            |
# | MySQL/PostgreSQL  | Relational DB       | Structured data storage & queries              |
# | MongoDB           | NoSQL Database      | Document store                                 |
# | Tableau / Power BI| BI / Visualization  | Dashboards and storytelling                    |
# | Docker            | Containerization    | Reproducible environments                      |

# %% [markdown]
# ## Arithmetic Expressions in Python
# You can use Python as a calculator. Examples include:
# - Addition: `a + b`
# - Multiplication: `a * b`
# - Exponentiation: `a ** b`
# - Modulo (remainder): `a % b`

# %%
# Multiply and add two numbers
a = 7
b = 5
product = a * b
summation = a + b
product, summation
# Out:
# (35, 12)

# %%
# Convert minutes to hours (with remainder minutes for clarity)
def minutes_to_hours(m):
    hours = m // 60
    minutes = m % 60
    return hours + minutes/60

example_minutes = 130
hours_value = minutes_to_hours(example_minutes)
hours_value
# Out:
# 2.1666666666666665

# %% [markdown]
# ## Objectives
# - Practice Markdown formatting (headers, lists, tables)
# - List common languages, libraries, and tools
# - Write simple Python expressions
# - Convert units with a tiny helper function
# - Share a Jupyter notebook via GitHub

# %% [markdown]
# **Author:** Bingkun Luo
# **Date:** 2025-11-09
